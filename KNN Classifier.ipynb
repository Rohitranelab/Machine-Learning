# %% [markdown]
# # KNN Classifier

# %% [markdown]
# ## Import Library

# %%
import pickle
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(r'student_dataset.csv')
df.head()
# Out:
#    study_hours  attendance  ...  exam_score  placement_status
# 0            7          56  ...      100.00            Placed
# 1            4          69  ...      100.00            Placed
# 2           11          60  ...      100.00            Placed
# 3            8          99  ...       90.17            Placed
# 4            5          52  ...       78.82            Placed
#
# [5 rows x 8 columns]

# %%
df['placement_status'].value_counts()
# Out:
# placement_status
# Placed        8356
# Not Placed    1644
# Name: count, dtype: int64

# %% [markdown]
# ## Convert text to numbers

# %%
le = LabelEncoder()

# %%
df['placement_status'] = le.fit_transform(df['placement_status'])

# %% [markdown]
# ## Features and Target

# %%
x = df.drop(columns = ['placement_status'], axis = 1)
y = df['placement_status']

# %% [markdown]
# ## Split Dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Handle Imbalanced Data

# %%
smote = SMOTE()

# %%
x_train, y_train = smote.fit_resample(x_train, y_train)

# %% [markdown]
# ## Create KNN Classifer Model

# %%
model = KNeighborsClassifier(n_neighbors = 5)

# %% [markdown]
# ## Train Model

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Predict

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Check Accuracy

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.979

# %% [markdown]
# ## Predict New Data

# %%
new_data = [[11, 99, 5, 6, 10, 60, 100]]
prediction = model.predict(new_data)
prediction
# Out:
# C:\Users\ROHIT RANE\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# ## Save Model

# %%
with open('KNN.pkl', 'wb') as file:
    pickle.dump(model, file)
