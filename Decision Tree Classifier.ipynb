# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# ## Import Library

# %%
import pickle
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Create Dataset

# %%
a, b = make_classification(n_samples = 10000, n_features =  10, random_state = 42)

df = pd.DataFrame(a)
df['target'] = b

# %%
df.head()
# Out:
#           0         1         2         3  ...         7         8         9  target
# 0  0.633563  0.357385 -0.503931  0.935066  ...  2.081684  0.041266 -0.258298       1
# 1  1.283905  1.109459 -0.908953  1.006586  ... -0.172200  1.150359  0.147744       1
# 2 -0.966476 -0.593314  0.458020  1.032323  ...  0.434477  0.423678  1.251380       1
# 3  2.429309 -1.306530 -1.869925  3.092164  ... -0.101213 -1.624066  0.443553       1
# 4 -1.204798  0.078464  0.705181  0.224765  ...  2.325055  0.495505  0.538133       0
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Features and Target

# %%
x = df.drop(columns  = ['target'], axis = 1)
y = df['target']

# %% [markdown]
# ## Split Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Create Decision Tree Model

# %%
model = DecisionTreeClassifier()

# %% [markdown]
# ## Train Model

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predict

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Check Accuracy

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0

# %% [markdown]
# ## Predict New Data

# %%
new_data = [[0.633563, 0.357385, -0.503931, -0.556895, 0.647981, -0.050796, -1.933989, 2.081684, 0.041266, -0.258298]]
prediction = model.predict(new_data)
print(prediction)
# Out:
# [0]

# %% [markdown]
# ## Save Model

# %%
with open('decisiontree.pkl', 'wb') as file:
    pickle.dump(model, file)
