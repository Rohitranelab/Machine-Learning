# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### Import Library

# %%
import pickle
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv(r'student_dataset.csv')
df.head()
# Out:
#    study_hours  attendance  ...  exam_score  placement_status
# 0            7          56  ...      100.00            Placed
# 1            4          69  ...      100.00            Placed
# 2           11          60  ...      100.00            Placed
# 3            8          99  ...       90.17            Placed
# 4            5          52  ...       78.82            Placed
#
# [5 rows x 8 columns]

# %%
df['placement_status'].value_counts()
# Out:
# placement_status
# Placed        8356
# Not Placed    1644
# Name: count, dtype: int64

# %% [markdown]
# ### Convert text to numbers

# %%
le = LabelEncoder()

# %%
df['placement_status'] = le.fit_transform(df['placement_status'])

# %% [markdown]
# ### Features and Target

# %%
x = df.drop(columns = ['placement_status'], axis = 1)
y = df['placement_status']

# %% [markdown]
# ### Split Dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ### Handle Imbalanced Data

# %%
smote = SMOTE()

# %%
x_train, y_train = smote.fit_resample(x_train, y_train)

# %% [markdown]
# ### Create Logistic Regression Model

# %%
model = LogisticRegression()

# %% [markdown]
# ### Train Model

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\ROHIT RANE\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### Predict

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ### Check Accuracy

# %%
print('Accuracy: ', accuracy_score(y_pred, y_test))
# Out:
# Accuracy:  0.9995

# %% [markdown]
# ### Predict New Data

# %%
new_data = [[7, 88, 8, 5, 10, 74, 100]]
prediction = model.predict(new_data)
print(prediction)
# Out:
# [1]
# C:\Users\ROHIT RANE\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Save Model

# %%
with open('LogisticRegression.pkl', 'wb') as f:
    pickle.dump(model, f)
